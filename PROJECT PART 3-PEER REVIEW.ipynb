# %%
PROJECT PART 2

# %% [markdown]
# Specifications (PROJECT PART-2)
# Section 1: Data and research questions
# o Here is the link for paper:
# https://www.nature.com/articles/nature22992#Sec7.
# o This is the third dataset in from project part 1.
# What are observations? How many, and how were they collected?
# • Each breast cancer patient is one observation. The authors collected the tumor
# samples from 363 Mexican and Spanish patients and formalin-fixed those samples.
# They extracted the DNA from the tumor samples and tested them for ER, PR and
# HER2 status. For mutational analysis, the samples were sequenced using Agilent
# SureSelect Exome Plus baits. Their age and clinical characteristics like tumor
# histology and ancestry were also recorded and measured.
# • Every time a patient sample is processed to measure these features is one
# observation.
# What are the features? How many, and what do they tell us about the observations
# • There are 13 features in this data. Mean target coverage for tumor and normal
# tissues, total covered bases, contamination scores, the number of mutations
# identified, mutation rates per megabase, details about specific mutations (APOBEC
# and BRCA), C>T mutations and clinical characteristics like ER, PR, and HER2 status,
# age. Clinical features such as the patient's age, tumor histology, ancestry, and the
# source of the sample collection are also included.
# • These features like clinical, genetic, and demographic factors help understanding
# mutation rate variability in breast cancer.
# What other data or knowledge are used?
# They also validate their findings using previously published breast cancer whole genomes
# (98 patients from TCGA and 560 from BRCA560) and targeted sequencing of 46 breast
# cancer cells lines.
# Describe how the data relates to the research question the authors were asking, and
# one other research question that you could ask
# The authors hypothesized that mutations in promoter regions can lead to functional
# changes in gene expression that promote cancer. They thought that these mutations in
# non-coding regions could occur as frequently as coding region mutations and have
# significant impacts on cancer progression. The data help them in  identifying of mutations
# in promoter regions, essential for detecting rare mutations that might alter gene
# expression.
# Describe one other research question that could be asked using this data, why this
# data would be useful for that purpose
# We can see whether the age of patients and hormone receptor status have a combined
# effect on the mutation rate in the breast cancer patients. We can use this data to be
# answered whether certain aggressive forms of breast cancer like triple negative have a
# higher mutation rate earlier than the patients with triple positive breast cancer and other
# combinations of hormone receptor status.
# Section 2: visualizations and data summaries (Figure has to use the data)
# Describe how it was generated: what are the axes? what are the individual data
# points? Or what are the cells in the table
# Describe why the authors chose to include that particular figure. How does it
# contribute to the overall arguments of the paper, or support the hypothesis, or show
# some characteristic of the data
# Figure 1: Identification of significantly mutated promoters.
# ![image.png](attachment:690df237-3570-4e2b-9c79-f8792e75ec49.png)
# Panel a
# •  This is a Q-Q plot that compares observed p-values of promoter mutation rates to
# the expected p-values.
# • Each data point is on the plot is a gene promoter region.
# • The x-axis represents the expected p-values if there were no association between
# mutations and promoter regions of genes, which they would expect in case of null
# hypothesis. The y-axis represents the observed p values from the data.
# • The data points above the black line showed the observed p values that are lower
# than expected.  This plot supports the hypothesis of authors that certain promoter
# regions in the genome are more frequently mutated in cancer patients than would
# be expected by a random chance.
# • The red dots in this plot highlight promoters with mutations that are statistically
# significant even after correction for false discovery, meaning these are not random
# occurrences but are potentially involved in breast cancer development and
# progression. They concluded that mutations in the promoter regions of certain
# genes like TBC1D12, ZNF143, CCDC107, NEAT1 etc. show significantly higher
# mutation rates than expected by chance, as highlighted in panel a.
# Panel b
# • Panel b in this figure shows mutation density plots for significant promoter regions
# identified in the study. To generate these plots, the authors selected the specific
# promoter regions associated with genes of interest based on their primary analysis
# (as shown in Figure 1-a). Then they mapped all the detected mutations in their
# breast cancer cohort. For each promoter region they calculated the mutation
# density and read coverage across the region.
# • The x-axis in all plots in panel b showed the position along the promoter region and
# nearby elements for each gene. Untranslated region (UTR) Showed as thin black
# bars while Protein-Coding Region represented by thick black bars on the schematic
# at the bottom of each plot. Intron are represented by dashed lines. The y axis has
# two components: The left y axis shows the number of mutations at each position
# along with the promoter. Peaks in this axis indicate areas with high mutation
# clustering. The right y-axis shows the coverage which is represented by grey shaded
# area. What I understood is that high coverage values show regions with greater read
# coverage, helping to confirm that observed mutations are not due to low coverage.
# • Red lollipops represent the mutations associated with the dataset generated by the
# authors. Additionally, they have included reported mutations from other studies.
# Green lollipops showed data from 98 TCGA breast cancer patients. Purple lollipops
# showed data from 560 breast cancer patients from a dataset “BRCA560”.
# • This plot helped the authors to identify significant mutation clustering within the
# promoter regions specifically. This clustering suggests that these promoter
# mutations may play a role in oncogenesis by altering gene regulation rather than the
# protein-coding sequence itself. It means they are the most important recurring and
# regulatory mutations that can potentially promote breast cancer.
# • We can conclude that FOX1, NEAT1 and RMPR (I also read the discussion section
# of paper for clarifications) have the mutations clustered in the untranslated region
# which is upstream to protein coding region and include the promoter regions.
#
#
# Figure 4: Power analysis of ExomePlus patient cohort.
# ![image.png](attachment:8431ce8e-d2fc-4c12-89d9-02aa90c2f316.png)
# o
# Describe how it was generated: what are the axes? what are the individual data points? Or
# what are the cells in the table
# Describe why the authors chose to include that particular figure. How does it contribute to
# the overall arguments of the paper, or support the hypothesis, or show some characteristic
# of the data
# Panel a
# • This panel shows how many patients the author needed to include to have a good
# chance of detecting specific mutations. This data includes the deep sequencing
# data.
# • The x axis shows the number of patients that starts from 10 and goes up to 1000. As
# you move to the right on x axis, you are looking at a greater number of patients. The y
# axis shows value for power which is a degree of how likely they are to detect a
# mutation with certain number of patients.
# • Blue line indicates mutations in 20% of patients, green line indicates mutations in
# 10% of patients, orange and teal line indicates mutations in 5% and 3% of patients
# respectively. The red horizontal line is drawn at the 90% power level. The black
# vertical line at 360 patients represents the size of the patient group they used in this
# study.
# • They included this analysis to indicate that small sample sizes likely led previous
# studies to overlook significant promoter mutations like those in FOXA1 (more in their
# discussion section). And, that their sample size (360 patients) was good enough to
# detect these mutations.
# Panel b
# • This is a bar plot that shows the percentage of patients who have mutations in
# specific promoters and protein-coding genes. Each bar represents a different gene
# or promoter. The orange bars show protein-coding regions and blue bars for
# promoters.
# • The x-axis shows the type of mutations, and the y axis shows the percentage of
# patients in the sample.
# • The authors included this plot to see the percentage of patients that have mutations
# in these gene coding and promoter regions.
# • One can conclude that even the significantly mutated promoters that were
# identified by authors in the previous sections of their study still have a lower
# percentage of patients as compared to the frequently mutated coding genes.
# Panel c
# • This is a density plot that shows the distribution of mutation rates per Mega base for
# different genes and promoters within the sample population. To generate this the
# authors must have used the mutation rate values from the data table.
# • The x-axis shows the average mutation rate per megabase in candidate gene coding
# and promoter. The blue peaks indicate promoters and orange peaks indicate protein
# coding regions. The y-axis plots density which shows how frequent certain mutation
# rates are across the genes and promoters.
# • This plot helped authors to highlight genes and promoters with high average
# mutation rates, which may indicate genomic regions prone to mutations or
# significant in the context of cancer.
# Conclusion for both panel b and c: I understood by reading the paper that a gene or
# promoter might have a high mutation rate (as shown in Panel c) but affect a smaller
# number of patients (Panel b). Take the example of FOXA1, it shows a high mutation rate
# in Panel c, but if it affects a smaller portion of the patients if we see the bar height in
# panel b.
# Describe one other figure or table that you might make that would be useful for
# understanding this data. Explain exactly what the axes or entries in would be the table,
# and include a sketch/mockup of what you expect it would look like. Explain why it
# would be useful and what it might show.
# • I would like to see a scatter plot that compares mutation rate with patient age, and
# data points would be color-coded by hormone receptor status.
# • I noticed in the data table that comparatively younger triple negative patients
# show more mutation rate as compared to the other patients. That is why I would
# like to see if there is a relationship among age of patients, hormone receptor status
# and mutation rate.
# • This plot will also determine if older patients generally have higher mutation rates
# and the aggressive forms of breast cancer like triple negative shows high mutation
# rate even at a comparatively younger age.
# Axes and Plot Details:
# X-axis will have patient age and y axis will have mutation rate. The data points would be
# each breast cancer patient that would be color coded by hormone receptor status.
# Mutation rate
# Triple negative
# ER+/PR+/HER2
# HER2+
# Patient’s Age
# Section 3: describe the data files you downloaded. You can open them in Excel or look
# at them with command line. For each file:
# Describe the number of rows and columns and how the file relates to the data in the
# paper.
# Describe the format of the data including the delimiters.
# Table S1:
# • There are 363 rows and 20 columns in this data table. The rows are observations for
# each corresponding (e.g., BDD-016, BDD-209…….). The row contains information
# like if a patient is HER2 positive or negative, how many BRACA mutations there are
# and information about other features. The columns are features includes for
# example BRCA mutations, mutation rate, ER status, PR status, HER2 status, age etc
# • The data is organized in an Excel spreadsheet in tabular form. Columns are
# separated by headers, each detailing the variable or attribute name, such as
# "Patient," "Total coverage," etc.

# %% [markdown]
# PROJECT PART 3

# %% [markdown]
# Here is the link for paper: https://www.nature.com/articles/nature22992#Sec7. The data is from their supplementary section:
# https://static-content.springer.com/esm/art%3A10.1038%2Fnature22992/MediaObjects/41586_2017_BFnature22992_MOESM2_ESM.xlsx.
# The supplementary file contains 8 tables. Table 1 the mutation analysis data from the patient cohort (N=363).
# I only needed the Table 1, so I saved the first excel sheet "Table 1-Patient summary" to csv format (mutations_dataset 2).

# %% [markdown]
# We used Pandas to read the data in our class. However, Pandas has no function to read the excel file that is why I converted the excel file into csv format. As,now the Data is in csv format, I can use pandas function to read this datafile as we did a lot of times in class with other datasets.

# %%
import pandas as pd
mutations_df = pd.read_csv("mutations_dataset 2.csv")
mutations_df
# Out:
#         Patient dbGAP ID  MEAN_TARGET_COVERAGE_TUMOR  \
# 0       BDD-016      016                   98.661186
# 1       BDD-017      017                   86.832640
# 2       BDD-023      023                   84.207498
# 3       BDD-024      024                   84.941686
# 4       BDD-028      028                   77.049478
# ..          ...      ...                         ...
# 357   BDD-YL9HM    YL9HM                   86.689018
# 358   BDD-ZCCFF    ZCCFF                   75.310611
# 359   BDD-ZP8D9    ZP8D9                   87.402512
# 360  MEX-BR-095      NaN                         NaN
# 361  MEX-BR-168      NaN                         NaN
#
#      MEAN_TARGET_COVERAGE_NORMAL  Total covered bases  \
# 0                      86.480413          141091104.0
# 1                      95.044451          140460129.0
# 2                      83.311891          139303471.0
# 3                      64.737617          139640168.0
# ...

# %% [markdown]
# Using head function to display first five rows of the dataset.

# %%
mutations_df.head()
# Out:
#    Patient dbGAP ID  MEAN_TARGET_COVERAGE_TUMOR  MEAN_TARGET_COVERAGE_NORMAL  \
# 0  BDD-016      016                   98.661186                    86.480413
# 1  BDD-017      017                   86.832640                    95.044451
# 2  BDD-023      023                   84.207498                    83.311891
# 3  BDD-024      024                   84.941686                    64.737617
# 4  BDD-028      028                   77.049478                    80.564986
#
#    Total covered bases  oxoG contamination score  FFPE contamination score  \
# 0          141091104.0                     43.18                     78.39
# 1          140460129.0                     43.02                     78.12
# 2          139303471.0                     41.42                     77.96
# 3          139640168.0                     41.57                     78.18
# 4          138147663.0                     40.87                     77.28
#
# ...

# %% [markdown]
# 3.2: Describe data numerically

# %%
mutations_df.shape
# Out:
# (362, 21)

# %% [markdown]
# There are 362 rows and 21 columns in this data table.
# The rows are observations for each corresponding (e.g., BDD-016, BDD-209…….). The row contains the information like if a patient is HER2 positive or negative, how many BRACA mutations are there and information about other features.
# The columns are features includes for example BRCA mutations, mutation rate, ER status, PR status, HER2 status, age etc.

# %% [markdown]
# I would choose Mutation rate and Ancestry as two features to investigate. The Ancestry feature in the dataset is likely a categorical variable representing the genetic background of individuals, such as Asian, Caucasian, or South Asian. The describe function for this feature will provide the count of observations with recorded ancestry, the number of unique categories, the most frequent category, and its frequency. For example, we might expect the dataset to show a count of 100 observations, with 5 distinct ancestry groups, and the most common category (e.g., "Asian") appearing in 50 observations. In contrast, the Mutation Rate/Mb feature represents a continuous, numeric value indicating the rate of mutations per megabase of DNA. The describe function for this feature will return the count of observations with recorded mutation rates, the mean (average mutation rate), the standard deviation (indicating variability), the minimum and maximum mutation rates, and the percentiles (25%, 50%, 75%).

# %%
mutation_rate = mutations_df['Mutation rate/Mb'].describe()
age = mutations_df['Ancestry'].describe()
age
# Out:
# count       362
# unique        5
# top       Asian
# freq        193
# Name: Ancestry, dtype: object

# %%
mutation_rate
# Out:
# count    360.000000
# mean       1.914421
# std        2.015853
# min        0.053412
# 25%        0.748965
# 50%        1.243983
# 75%        2.296518
# max       16.107568
# Name: Mutation rate/Mb, dtype: float64

# %% [markdown]
# I would make a violin plot to compare the mutation rate among all ancestry groups.
# It visually summarizes the distribution of mutation rates for each ancestry group.
# It highlights medians, interquartile ranges, and potential outliers, giving a clear comparative view.
# It helps identify trends, such as whether the Asian group has consistently higher mutation rates.
# Code explanation:
# First, calculate the average mutation rate per ancestry group using groupby and mean.
# Then, create a violin plot to show the distribution of "Mutation rate/Mb" across different ancestry groups.
# The authors hypothesize that mutations in promoter regions, despite being in non-coding areas, may have significant functional impacts on gene expression and cancer progression.
# The violin plot shows the distribution rather than just the average mutation rate. This is important because it may reveal:
# Populations with wider variability (some individuals may have extremely high mutation rates).
# Overlapping or distinct trends between groups, which can indicate shared or unique mutation dynamics.

# %%
mutation_rate=['Mutation rate/Mb']
x=mutations_df.groupby("Ancestry")
x[mutation_rate].mean()
# Out:
#                   Mutation rate/Mb
# Ancestry
# African American          3.319174
# Asian                     1.799261
# Caucasian                 1.992085
# Hispanic                  1.957732
# South Asian               4.518515

# %%
import seaborn as sns
sns.catplot(data=mutations_df, x='Ancestry', y='Mutation rate/Mb', kind='violin')

# %% [markdown]
# The plot shows how frequently these mutations occur in triple-positive versus triple-negative cancers.If triple-positive cancers show more C>T CpG mutations, it may indicate a higher prevalence of mutations in regulatory regions that drive this subtype. Differences in C>T CpG mutation rates may reflect distinct biological processes or vulnerabilities in triple-positive vs. triple-negative cancers.For example, triple-positive cancers may depend more on specific gene regulatory pathways.
#
# Code Explanation: A new column named Triple Negative is created in the dataframe, and all rows are initially assigned the value 'No'. This sets the default assumption that a sample is not triple-negative. Then I use catplot function to make a box plot that compares the C>T CpG mutation rates in patients with triple negative and other group.
#
# The visualization will either confirm or challenge the paper's hypothesis that mutations in non-coding regions, particularly promoter mutations, could be driving changes in gene expression. By comparing mutation rates between triple-positive and triple-negative samples, you can begin to understand whether these regions are more prone to mutations in one group and potentially have an outsized impact on cancer development.This facilitates downstream analyses, such as comparing mutation rates or age distribution between triple-negative and non-triple-negative samples.

# %%
# Create the 'Triple Negative' column using pandas indexing
mutations_df['Triple Negative'] = 'No'  # Default value
mutations_df.loc[ (mutations_df['HER2'] == 'Negative') &  (mutations_df['ER'] == 'Negative') & (mutations_df['PR'] == 'Negative'),  'Triple Negative'] = 'Yes'

# Display the first few rows to verify
(mutations_df[['HER2', 'ER', 'PR', 'Triple Negative', 'Age','BRCA_mutations']])
# Out:
#          HER2        ER        PR Triple Negative   Age  BRCA_mutations
# 0    Negative  Negative  Negative             Yes  59.0      187.812851
# 1    Negative  Negative  Negative             Yes  49.0      357.671244
# 2    Negative  Negative  Negative             Yes  45.0      382.950460
# 3    Negative  Negative  Negative             Yes  44.0      446.594042
# 4    Positive  Positive  Positive              No  87.0      289.971607
# ..        ...       ...       ...             ...   ...             ...
# 357  Negative  Positive  Negative              No  57.0      100.714725
# 358  Positive  Negative  Negative              No  38.0       63.202169
# 359       NaN  Negative  Negative              No  45.0       29.001449
# 360  Negative  Positive  Negative              No  52.0             NaN
# 361  Negative  Negative       NaN              No  56.0             NaN
#
# [362 rows x 6 columns]

# %%
    sns.catplot(data=mutations_df, x='Triple Negative', y='C>T_CpG_mutations', kind='box')
